# %% [markdown]
# <center><h1>Python Matplotlib</h1></center>

# %% [markdown]
# <left><h3>Importing the Matplotlib</h3></left>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <left><h3>Importing the Numpy and Pandas</h3></left>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([6,7,8,9,10])
plt.plot(xpoints, ypoints)
plt.title("Sample graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis, y axis and a title

# %%
xpoints=np.array([1,2,3,4,5])
ypoints=np.array([6,7,8,9,10])
plt.plot(xpoints, ypoints)
plt.title("Sample graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.<br>
# Test Data:<br>
# test.txt<br>
# 1 2<br>
# 2 4<br>
# 3 1

# %%
num_array1=[]
num_array2=[]
with open("test.txt","r") as file:
    for line in file:
        x,y=map(int,line.split())
        num_array1.append(x)
        num_array2.append(y)

xpoints=np.array(num_array1)
ypoints=np.array(num_array2)
plt.plot(xpoints,ypoints)
plt.title("Text Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.<br>
# Sample Financial data (fdata.csv):<br>
# Date,Open,High,Low,Close<br>
# 03-10-16,774.25,776.065002,769.5,772.559998<br>
# 04-10-16,776.030029,778.710022,772.890015,776.429993<br>
# 05-10-16,779.309998,782.070007,775.650024,776.469971<br>
# 06-10-16,779,780.47998,775.539978,776.859985<br>
# 07-10-16,779.659973,779.659973,770.75,775.080017

# %%
data_frame=pd.read_csv("fdata.csv")
print(data_frame)

plt.subplot(2,2,1)
plt.plot(data_frame["Date"],data_frame["Open"])
plt.title("Opening")
plt.xlabel("Date",fontsize=1)

plt.subplot(2,2,2)
plt.plot(data_frame["Date"],data_frame["Close"])
plt.title("Closing")
plt.xlabel("Date",fontsize=1)

plt.subplot(2,2,3)
plt.plot(data_frame["Date"],data_frame["Low"])
plt.title("Low")
plt.xlabel("Date",fontsize=1)

plt.subplot(2,2,4)
plt.plot(data_frame["Date"],data_frame["High"])
plt.title("High")
plt.xlabel("Date",fontsize=1)
plt.suptitle("Alphabet Inc.")
plt.show()
# Out:
#        Date        Open        High         Low       Close
# 0  03-10-16  774.250000  776.065002  769.500000  772.559998
# 1  04-10-16  776.030029  778.710022  772.890015  776.429993
# 2  05-10-16  779.309998  782.070007  775.650024  776.469971
# 3  06-10-16  779.000000  780.479980  775.539978  776.859985
# 4  07-10-16  779.659973  779.659973  770.750000  775.080017

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each
# line.

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1)
plt.plot(num_array2)
plt.legend([1,2],title="Lines")
plt.show()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1,"-r",linewidth=5)
plt.plot(num_array2,"-g",linewidth=15)
plt.legend([1,2],title="Lines")
plt.show()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1,":r")
plt.plot(num_array2,"--g")
plt.legend([1,2],title="Lines")
plt.show()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1,"*:r")
plt.plot(num_array2,"o--g")
plt.legend([1,2],title="Lines")
plt.show()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values.

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1,"*:r")
plt.plot(num_array2,"o--g")
plt.legend([1,2],title="Lines")
print(plt.xlim)
print(plt.ylim)
plt.xlim=(2,5)
plt.ylim(1, 10)
plt.show()
# Out:
# (2, 8)
# <function ylim at 0x000001BE8AF409A0>

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %%
num_array1=np.array([1,2,3,4,5])
num_array2=np.array([6,7,8,9,10])
plt.plot(num_array1,num_array2, "*:r", label="Quantities")
plt.show()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command
# using arrays.

# %%
num_array1=np.arange(1,5,0.5)
plt.plot(num_array1,num_array1,":g",num_array1,num_array1**2,"--r",num_array1,num_array1**3,"-.y")
plt.legend([1,2,3],title="Power")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.show()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
num_array1=np.arange(1,5,0.5)
plt.plot(num_array1,num_array1,":g")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Normal")
plt.show()
plt.plot(num_array1,num_array1**2,"--r")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Raised to power 2")
plt.show()
plt.plot(num_array1,num_array1**3,"-.c")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Raised to power 3")
plt.show()

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of<br>
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with<br>
# linestyle -, width .5. and color blue.<br>
# Date,Close<br>
# 03-10-16,772.559998<br>
# 04-10-16,776.429993<br>
# 05-10-16,776.469971<br>
# 06-10-16,776.859985<br>
# 07-10-16,775.080017

# %%
data_frame=pd.read_csv("fdata.csv")
print(data_frame)
plt.plot(data_frame["Date"],data_frame["Open"],"--b",linewidth=0.5)
plt.xlabel("Date")
plt.ylabel("Open")
plt.title("Opening Rate")
plt.show()
plt.plot(data_frame["Date"],data_frame["Close"],"--b",linewidth=0.5)
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("Closing Rate")
plt.show()
plt.plot(data_frame["Date"],data_frame["Low"],"--b",linewidth=0.5)
plt.xlabel("Date")
plt.ylabel("Low")
plt.title("Lowest Rate")
plt.show()
plt.plot(data_frame["Date"],data_frame["High"],"--b",linewidth=0.5)
plt.xlabel("Date")
plt.ylabel("High")
plt.title("Highest Rate")
plt.show()
# Out:
#        Date        Open        High         Low       Close
# 0  03-10-16  774.250000  776.065002  769.500000  772.559998
# 1  04-10-16  776.030029  778.710022  772.890015  776.429993
# 2  05-10-16  779.309998  782.070007  775.650024  776.469971
# 3  06-10-16  779.000000  780.479980  775.539978  776.859985
# 4  07-10-16  779.659973  779.659973  770.750000  775.080017

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn
# off ticks.

# %%
data_frame=pd.read_csv("fdata.csv")
print(data_frame)
plt.plot(data_frame["Date"],data_frame["Open"],"--b",linewidth=0.5)
ax=plt.gca()
plt.xlabel("Date")
plt.ylabel("Open")
plt.title("Opening Rate")
plt.minorticks_on()
ax.grid(which="Major",linewidth=1.0)
ax.grid(which="Minor",linewidth=0.5)
plt.tick_params(labelleft=False,labelbottom=False)
plt.show()
# Out:
#        Date        Open        High         Low       Close
# 0  03-10-16  774.250000  776.065002  769.500000  772.559998
# 1  04-10-16  776.030029  778.710022  772.890015  776.429993
# 2  05-10-16  779.309998  782.070007  775.650024  776.469971
# 3  06-10-16  779.000000  780.479980  775.539978  776.859985
# 4  07-10-16  779.659973  779.659973  770.750000  775.080017

# %% [markdown]
# 15. Write a Python program to create multiple plots.

# %%
num_array1=np.arange(1,5,0.5)
plt.subplot(5,1,1)
plt.plot(num_array1,num_array1,":g")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Normal")

plt.subplot(5,1,3)
plt.plot(num_array1,num_array1**2,"--r")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Raised to power 2")

plt.subplot(5,1,5)
plt.plot(num_array1,num_array1**3,"-.c")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Raised to power 3")
plt.show()
